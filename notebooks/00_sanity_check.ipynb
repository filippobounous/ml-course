# %% [markdown]
# # Week 0 sanity check
#
# If you can run this notebook, your environment is working.

# %%
import numpy as np
import pandas as pd

x = np.arange(5)
df = pd.DataFrame({"x": x, "x2": x**2})
df
